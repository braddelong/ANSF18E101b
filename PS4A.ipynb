# %% [markdown]
# # Econ 101b (Fall 2018) Problem Set 4—with Answers

# %% [markdown]
# ### Problem set will be due Fri Sep 14 at midnight...
#
# #### Sections between Tu AM & Th AM lecture will be problem set section...

# %% [markdown]
# ## Setting up the Python/Jupyter environment

# %%
# %%javascript
#
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;}

# %%
# keep output cells from shifting to autoscroll: little scrolling
# subwindows within the notebook are an annoyance...

# %%
# set up the environment by reading in every library we might need: 
# os... graphics... data manipulation... time... math... statistics...

import sys
import os
from urllib.request import urlretrieve

import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Image

import pandas as pd
from pandas import DataFrame, Series
from datetime import datetime

import scipy as sp
import numpy as np
import math
import random

import seaborn as sns
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf

# graphics setup: seaborn-whitegrid and figure size;
# graphs in the notebook itself...

# %matplotlib inline 

plt.style.use('seaborn-whitegrid')

figure_size = plt.rcParams["figure.figsize"]
figure_size[0] = 12
figure_size[1] = 10
plt.rcParams["figure.figsize"] = figure_size

# %%
# Don't change this cell; just run it. 
# The result will give you directions about how to log in to the submission system, called OK.
# Once you're logged in, you can run this cell again, but it won't ask you who you are because
# it remembers you. However, you will need to log in once per assignment.

# !pip install -U okpy

from client.api.notebook import Notebook

ok = Notebook('ps4.ok')
_ = ok.auth(force=True, inline=True)
# Out:
# Requirement already up-to-date: okpy in /anaconda3/lib/python3.6/site-packages (1.13.11)
# Requirement not upgraded as not directly required: requests==2.12.4 in /anaconda3/lib/python3.6/site-packages (from okpy) (2.12.4)
# Requirement not upgraded as not directly required: coverage==3.7.1 in /anaconda3/lib/python3.6/site-packages (from okpy) (3.7.1)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# =====================================================================
# Assignment: PS4 Notebook
# OK, version v1.13.11
# =====================================================================
#
#
# Open the following URL:
#
# https://okpy.org/client/login/
#
# After logging in, copy the code from the web page and paste it into the box.
# Then press the "Enter" key on your keyboard.
#
# Paste your code here: zcelm9SdgIgrYElzLRtgtlMCPaia8I
# Successfully logged in as jbdelong@berkeley.edu

# %% [markdown]
# ### ⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎⬆︎
# ### RUN THESE CELLS ABOVE FIRST

# %% [markdown]
# **Task 1: Using information sources**:
#
# 1. Websurf your way over to https://gapminder.org/tools (if you do not see a list of countries, expand your window)
# 2. Choose a non-U.S. country of interest to you. Select it and the U.S. by clicking on the checkboxes in the country list that should be visible.
# 3. Pull the slider to the right of the "play" button all the way back to the left.
# 4. Press the "play" button and watch the two countries—the one you selected, and the U.S.—make tracks over the past.
# 5. Take a screenshot of the resulting figure when the animation has finished.
# 6. Upload that screenshot to a URL somewhere on the net.
# 7. Display that screenshot in the markdown cell below using an &lt;img src="" /&gt; tag
# 8. Write a paragraph: What do you learn about economic growth roughly since the Industrial Revolution from the figure you have screenshotted?

# %% [markdown]
# <font color="blue">PASTE IMG TAG HERE: ___  </font>

# %% [markdown]
# <font color="blue">WHAT DID YOU LEARN? ANSWER: ___ </font>

# %% [markdown]
# ----

# %% [markdown]
# **Task 2: Reversals of Fortune**:
#
# This problem requires you to edit the second Python code cell below. The first cell downloads data and plots Argentinean and Swedish levels of GDP per capita since 1890. Run this first cell. There is no need to change it. Then...

# %%
# time series for measured real national product per capita for 
# Sweden and Argentina since 1890, plus source notes, accessible 
# in the argentina_sweden_dict object for later use, if needed...

import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Image

import pandas as pd

sourceURL = "http://delong.typepad.com/2017-08-11-argentina-and-sweden-gdp-per-capita-1890-2015-from-gapminder.org.csv"
argentina_sweden_df = pd.read_csv(sourceURL, index_col = 0)

argentina_sweden_dict = {}
argentina_sweden_dict["df"] = argentina_sweden_df
argentina_sweden_dict["sourceURL"] = sourceURL
argentina_sweden_dict["sourceDescription"] = "Hans Rosling's Gapminder: http://gapminder.org"   
argentina_sweden_dict["sourceNotes"] = "From Gapminder World data page: http://www.gapminder.org/data/"

argentina_sweden_dict["df"].plot()

plt.ylim(0, )
plt.xlabel("Year", size = 15)
plt.ylabel("Real GDP per Capita", size = 15)
plt.title("Swedish and Argentinian Economic Growth since 1890", size = 30)
# Out:
# Text(0.5,1,'Swedish and Argentinian Economic Growth since 1890')

# %% [markdown]
# Then...

# %% [markdown]
# 2.1: Calculate the year that Sweden surpasses Argentina in GDP per capita. Write code to set the variable Sweden_surpasses equal to that year in the code cell below:

# %%
Sweden_surpasses = ___

# %%
# ANSWER

print(argentina_sweden_dict["df"][40:])

Sweden_surpasses = 1931
# Out:
#       Argentina  Sweden
# Year
# 1930       7439    7317
# 1931       6709    7142
# 1932       6293    6875
# 1933       6402    7000
# 1934       6715    7465
# 1935       6810    7821
# 1936       6689    8092
# 1937       6997    8305
# 1938       6839    8573
# 1939       6923    9199
# 1940       6859    8517
# 1941       7042    8278
# 1942       6943    8340
# 1943       6724    8598
# 1944       7309    8840
# 1945       6898    9088
# 1946       7289    9985
# 1947       7862   10787
# 1948       8041   10925
# 1949       7687   11278
# 1950       7540   11977
# 1951       7612   11890
# 1952       7019   12133
# 1953       7198   12221
# 1954       7305   12896
# 1955       7631   13177
# 1956       7652   13642
# 1957       7863   13956
# 1958       8157   14031
# 1959       7449   14598
# ...         ...     ...
# 1986       9810   29138
# 1987       9936   29889
# 1988       9620   30596
# 1989       8820   31161
# 1990       8539   30901
# 1991       9333   30340
# 1992      10130   29813
# 1993      10602   29028
# 1994      11108   30000
# 1995      10673   31044
# 1996      11150   31465
# 1997      11935   32360
# 1998      12268   33709
# 1999      11722   35208
# 2000      11504   36816
# 2001      10875   37292
# 2002       9574   37941
# 2003      10318   38702
# 2004      11135   40216
# 2005      12039   41184
# 2006      12913   42873
# 2007      13873   44005
# 2008      14646   43421
# 2009      14605   40820
# 2010      15765   42898
# 2011      16972   43709
# 2012      17101   43263
# 2013      17629   43448
# 2014      17519   44029
# 2015      17344   44892
#
# [86 rows x 2 columns]

# %%
ok.grade('q01')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
# {'passed': 1, 'failed': 0, 'locked': 0}

# %% [markdown]
# 2.2: Calculate the growth rates of Swedish and Argentinean GDP per capita, and their difference, over the periods 1890-1914, 1914-1946, 1946-1980, and 1980-2002. Write code to set the appropriate variables equal to the values in the code cell below:

# %%
Swedish_Growth18901914 = ___
Swedish_Growth19141946 = ___
Swedish_Growth19461980 = ___
Swedish_Growth19802002 = ___

Argentinean_Growth18901914 = ___
Argentinean_Growth19141946 = ___
Argentinean_Growth19461980 = ___
Argentinean_Growth19802002 = ___

Difference_Growth18901914 = ___
Difference_Growth19141946 = ___
Difference_Growth19461980 = ___
Difference_Growth19802002 = ___

# %%
# ANSWER

Swedish_Growth18901914 = (np.log(argentina_sweden_dict["df"]["Sweden"][1914]/
       argentina_sweden_dict["df"]["Sweden"][1890])/
       (1914-1890))

Swedish_Growth19141946 = (np.log(argentina_sweden_dict["df"]["Sweden"][1946]/
       argentina_sweden_dict["df"]["Sweden"][1914])/
       (1946-1914))

Swedish_Growth19461980 = (np.log(argentina_sweden_dict["df"]["Sweden"][1980]/
       argentina_sweden_dict["df"]["Sweden"][1946])/
       (1980-1946))

Swedish_Growth19802002 = (np.log(argentina_sweden_dict["df"]["Sweden"][2002]/
       argentina_sweden_dict["df"]["Sweden"][1980])/
       (2002-1980))

Argentinean_Growth18901914 = (np.log(argentina_sweden_dict["df"]["Argentina"][1914]/
       argentina_sweden_dict["df"]["Argentina"][1890])/
       (1914-1890))

Argentinean_Growth19141946 = (np.log(argentina_sweden_dict["df"]["Argentina"][1946]/
       argentina_sweden_dict["df"]["Argentina"][1914])/
       (1946-1914))

Argentinean_Growth19461980 = (np.log(argentina_sweden_dict["df"]["Argentina"][1980]/
       argentina_sweden_dict["df"]["Argentina"][1946])/
       (1980-1946))

Argentinean_Growth19802002 = (np.log(argentina_sweden_dict["df"]["Argentina"][2002]/
       argentina_sweden_dict["df"]["Argentina"][1980])/
       (2002-1980))

Difference_Growth18901914 = (np.log(argentina_sweden_dict["df"]["Sweden"][1914]/
       argentina_sweden_dict["df"]["Sweden"][1890])/
       (1914-1890))/(np.log(argentina_sweden_dict["df"]["Argentina"][1914]/
       argentina_sweden_dict["df"]["Argentina"][1890])/
       (1914-1890))

Difference_Growth19141946 = (np.log(argentina_sweden_dict["df"]["Sweden"][1946]/
       argentina_sweden_dict["df"]["Sweden"][1914])/
       (1946-1914))/(np.log(argentina_sweden_dict["df"]["Argentina"][1946]/
       argentina_sweden_dict["df"]["Argentina"][1914])/
       (1946-1914))

Difference_Growth19461980 = (np.log(argentina_sweden_dict["df"]["Sweden"][1980]/
       argentina_sweden_dict["df"]["Sweden"][1946])/
       (1980-1946))/(np.log(argentina_sweden_dict["df"]["Argentina"][1980]/
       argentina_sweden_dict["df"]["Argentina"][1946])/
       (1980-1946))

Difference_Growth19802002 = (np.log(argentina_sweden_dict["df"]["Sweden"][2002]/
       argentina_sweden_dict["df"]["Sweden"][1980])/
       (2002-1980))/(np.log(argentina_sweden_dict["df"]["Argentina"][1914]/
       argentina_sweden_dict["df"]["Argentina"][1890])/
       (1914-1890))

print("Swedish Growth 1890-1914 =", Swedish_Growth18901914)
print("Swedish Growth 1914-1946 =", Swedish_Growth19141946)
print("Swedish Growth 1946-1980 =", Swedish_Growth19461980)
print("Swedish Growth 1980-2002 =", Swedish_Growth19802002)
print(" ")

print("Argentinian Growth 1890-1914 =", Argentinean_Growth18901914)
print("Argentinian Growth 1914-1946 =", Argentinean_Growth19141946)
print("Argentinian Growth 1946-1980 =", Argentinean_Growth19461980)
print("Argentinian Growth 1980-2002 =", Argentinean_Growth19802002)
print(" ")

print("Difference in Growth 1890-1914 =", Difference_Growth18901914)
print("Difference in Growth 1914-1946 =", Difference_Growth19141946)
print("Difference in Growth 1946-1980 =", Difference_Growth19461980)
print("Difference in Growth 1980-2002 =", Difference_Growth19802002)
# Out:
# Swedish Growth 1890-1914 = 0.024660041602119907
# Swedish Growth 1914-1946 = 0.021972235391967382
# Swedish Growth 1946-1980 = 0.028158738605670048
# Swedish Growth 1980-2002 = 0.017161420095699497
#
# Argentinian Growth 1890-1914 = 0.012185525777567909
# Argentinian Growth 1914-1946 = 0.0012464046242647042
# Argentinian Growth 1946-1980 = 0.012055623719311912
# Argentinian Growth 1980-2002 = -0.006236658085743798
#
# Difference in Growth 1890-1914 = 2.023715845525196
# Difference in Growth 1914-1946 = 17.628493158816337
# Difference in Growth 1946-1980 = 2.3357346962117393
# Difference in Growth 1980-2002 = 1.408344654876658

# %% [markdown]
# 2.3: Calculate the multiple that Swedish GDP per capita in 2015 is of its level in 1890, the multiple that Argentinean GDP per capita in 2015 is of its level in 1890, and the multiple that the quotient is. Write code to set the appropriate variables equal to the values in the code cell below:

# %%
Sweden_multiple18902015 = ___

Argentina_multiple18902015 = ___

Quotient_multiple18902015 = ___

# %%
# ANSWER

Sweden_multiple18902015 = (argentina_sweden_dict["df"]["Sweden"][2015]/
                              argentina_sweden_dict["df"]["Sweden"][1890])

Argentina_multiple18902015 = (argentina_sweden_dict["df"]["Argentina"][2015]/
                                  argentina_sweden_dict["df"]["Argentina"][1890])

Quotient_multiple18902015 = Sweden_multiple18902015/Argentina_multiple18902015

print("Sweden multiple 1890-2015 = ", Sweden_multiple18902015)
print("Argentina multiple 1890-2015 = ", Argentina_multiple18902015)
print("Quotient multiple 1890-2015 = ", Quotient_multiple18902015)
# Out:
# Sweden multiple 1890-2015 =  16.413893967093237
# Argentina multiple 1890-2015 =  3.3175210405508797
# Quotient multiple 1890-2015 =  4.9476382414646825

# %% [markdown]
# ----

# %% [markdown]
# **Task 3: The basics of the Solow growth model**:
#
# In the (markdown) cell below this one, answer the questions asked:
#
# 1. What are the _economic variables_ in the Solow growth model? List their symbols, and describe what they are: ANSWER
#
# 2. What are the _parameters_ in the Solow growth model? List their symbols, and describe what they are:
#
# 3. What are the _behavioral relationships_ in the Solow growth model?
#
# 4. What is the _equilibrium condition_ in the Solow growth model?

# %% [markdown]
# 1. What are the _economic variables_ in the Solow growth model? List their symbols, and describe what they are: <font color='blue'>ANSWER: ___ </font>
#
# 2. What are the _parameters_ in the Solow growth model? List their symbols, and describe what they are: <font color='blue'>ANSWER: ___ </font>
#
# 3. What are the _behavioral relationships_ in the Solow growth model? <font color='blue'>ANSWER: ___ </font>
#
# 4. What is the _equilibrium condition_ in the Solow growth model? <font color='blue'>ANSWER: ___ </font>

# %% [markdown]
# ----
#
# &nbsp;

# %% [markdown]
# **Task 4: Equilibrium Output per Worker Graphically**
#
# The economic equilibrium we look for in the Solow Growth Model is the so-called balanced-growth equilibrium growth path. Along it, the economy's capital-output ratio is constant as the other economic variables in the model grow. If the capital-output ratio is at its balanced-growth equilibrium path value, it will stay there. If the capital-output ratio is away from its balanced-growth equilibrium path value, it will head there.
#
# In terms of the labor-force growth rate n, the efficiency-of-labor growth rate g, the capital depreciation rate &delta;, the savings-investment share of output Y, and the production function parameter &alpha;, the balanced-growth path value of the capital-output ratio is:
#
# $ {\left(\frac{K}{Y}\right)}^{*} = \frac{s}{(n+g+\delta)} $
#
# When the capital-output ratio is at that value, both the capital stock K and the level of output Y are growing at the same rate n+g.
#
# If you know that the economy is on its balanced-growth path, and if you know also the current value of the efficiency-of-labor E in the production function, you can then immediately calculate the economy's levels of output-per-worker Y/L and of capital-per-worker K/L.
#
# The code cell immediately below contains a small program to plot the balanced-growth path output per worker and capital per worker levels graphically for values of the parameters n, g, δ, α, and s, and for the current level of the efficiency of labor E. It is set to calculate for n = 0, g= 0, δ = .03, α = 0.5, s = 0.15, and E = 1.
#
# Alter the inputs to the cell above the line of "# ----" and rerun the cell multiple times, or use some other means of your choosing, to set the variables in the further cells below:

# %%
delta = 0.03
n = 0
g = 0
s = 0.15
alpha = 0.5
E = 1
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)

# %%
# 4.1 For n = 0, g= 0, δ = .03, α = 0.5, 
# s = 0.15, and E = 1.

YoverL41 = ___
KoverL41 = ___

# %%
# ANSWER

# 4.1 For n = 0, g= 0, δ = .03, α = 0.5, 
# s = 0.15, and E = 1.

YoverL41 = 5
KoverL41 = 25

# %%
ok.grade('q02')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
# {'passed': 1, 'failed': 0, 'locked': 0}

# %%
# 4.2 For n = 0.01, g = 0.01, δ = .03, α = 0.3333, 
# s = 0.25, and E = 2.

YoverL42 = ___
KoverL42 = ___

# %%
# ANSWER

delta = 0.03
n = 0.01
g = 0.01
s = 0.25
alpha = 0.3333333
E = 2
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[80:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 80                20.00           4.308869                   4.00
# 81                20.25           4.326748                   4.05
# 82                20.50           4.344481                   4.10
# 83                20.75           4.362070                   4.15
# 84                21.00           4.379519                   4.20
# 85                21.25           4.396829                   4.25
# 86                21.50           4.414005                   4.30
# 87                21.75           4.431047                   4.35
# 88                22.00           4.447960                   4.40
# 89                22.25           4.464745                   4.45
# 90                22.50           4.481404                   4.50
# 91                22.75           4.497941                   4.55
# 92                23.00           4.514357                   4.60
# 93                23.25           4.530655                   4.65
# 94                23.50           4.546836                   4.70
# 95                23.75           4.562902                   4.75
# 96                24.00           4.578857                   4.80
# 97                24.25           4.594701                   4.85
# 98                24.50           4.610436                   4.90
# 99                24.75           4.626065                   4.95
# 100               25.00           4.641588                   5.00
# 101               25.25           4.657009                   5.05
# 102               25.50           4.672328                   5.10
# 103               25.75           4.687548                   5.15
# 104               26.00           4.702669                   5.20
# 105               26.25           4.717694                   5.25
# 106               26.50           4.732623                   5.30
# 107               26.75           4.747459                   5.35
# 108               27.00           4.762203                   5.40
# 109               27.25           4.776856                   5.45
# ..                  ...                ...                    ...
# 171               42.75           5.550499                   8.55
# 172               43.00           5.561297                   8.60
# 173               43.25           5.572054                   8.65
# 174               43.50           5.582770                   8.70
# 175               43.75           5.593444                   8.75
# 176               44.00           5.604078                   8.80
# 177               44.25           5.614672                   8.85
# 178               44.50           5.625226                   8.90
# 179               44.75           5.635740                   8.95
# 180               45.00           5.646216                   9.00
# 181               45.25           5.656652                   9.05
# 182               45.50           5.667051                   9.10
# 183               45.75           5.677411                   9.15
# 184               46.00           5.687733                   9.20
# 185               46.25           5.698019                   9.25
# 186               46.50           5.708267                   9.30
# 187               46.75           5.718478                   9.35
# 188               47.00           5.728654                   9.40
# 189               47.25           5.738793                   9.45
# 190               47.50           5.748896                   9.50
# 191               47.75           5.758965                   9.55
# 192               48.00           5.768998                   9.60
# 193               48.25           5.778996                   9.65
# 194               48.50           5.788960                   9.70
# 195               48.75           5.798889                   9.75
# 196               49.00           5.808785                   9.80
# 197               49.25           5.818647                   9.85
# 198               49.50           5.828476                   9.90
# 199               49.75           5.838272                   9.95
# 200               50.00           5.848035                  10.00
#
# [121 rows x 3 columns]

# %%
# ANSWER

# 4.2 For n = 0.01, g = 0.01, δ = .03, α = 0.3333, 
# s = 0.25, and E = 2.

YoverL42 = 4.47
KoverL42 = 22.4

# %%
# 4.3 For n = 0.01, g= 0.02, δ = .03, α = 0.3333, 
# s = 0.36, and E = 1.

YoverL43 = ___
KoverL43 = ___

# %%
# ANSWER

capital_and_output_per_worker_df[40:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 40                10.00           2.154433               1.666667
# 41                10.25           2.172239               1.708333
# 42                10.50           2.189758               1.750000
# 43                10.75           2.207001               1.791667
# 44                11.00           2.223978               1.833333
# 45                11.25           2.240701               1.875000
# 46                11.50           2.257177               1.916667
# 47                11.75           2.273416               1.958333
# 48                12.00           2.289427               2.000000
# 49                12.25           2.305216               2.041667
# 50                12.50           2.320792               2.083333
# 51                12.75           2.336162               2.125000
# 52                13.00           2.351333               2.166667
# 53                13.25           2.366310               2.208333
# 54                13.50           2.381100               2.250000
# 55                13.75           2.395708               2.291667
# 56                14.00           2.410140               2.333333
# 57                14.25           2.424402               2.375000
# 58                14.50           2.438497               2.416667
# 59                14.75           2.452432               2.458333
# 60                15.00           2.466210               2.500000
# 61                15.25           2.479836               2.541667
# 62                15.50           2.493313               2.583333
# 63                15.75           2.506647               2.625000
# 64                16.00           2.519840               2.666667
# 65                16.25           2.532896               2.708333
# 66                16.50           2.545819               2.750000
# 67                16.75           2.558613               2.791667
# 68                17.00           2.571279               2.833333
# 69                17.25           2.583822               2.875000
# ..                  ...                ...                    ...
# 171               42.75           3.496591               7.125000
# 172               43.00           3.503394               7.166667
# 173               43.25           3.510170               7.208333
# 174               43.50           3.516920               7.250000
# 175               43.75           3.523645               7.291667
# 176               44.00           3.530344               7.333333
# 177               44.25           3.537018               7.375000
# 178               44.50           3.543666               7.416667
# 179               44.75           3.550290               7.458333
# 180               45.00           3.556889               7.500000
# 181               45.25           3.563463               7.541667
# 182               45.50           3.570014               7.583333
# 183               45.75           3.576540               7.625000
# 184               46.00           3.583043               7.666667
# 185               46.25           3.589523               7.708333
# 186               46.50           3.595979               7.750000
# 187               46.75           3.602411               7.791667
# 188               47.00           3.608821               7.833333
# 189               47.25           3.615209               7.875000
# 190               47.50           3.621574               7.916667
# 191               47.75           3.627916               7.958333
# 192               48.00           3.634236               8.000000
# 193               48.25           3.640535               8.041667
# 194               48.50           3.646812               8.083333
# 195               48.75           3.653067               8.125000
# 196               49.00           3.659301               8.166667
# 197               49.25           3.665514               8.208333
# 198               49.50           3.671705               8.250000
# 199               49.75           3.677876               8.291667
# 200               50.00           3.684027               8.333333
#
# [161 rows x 3 columns]

# %%
# ANSWER

delta = 0.03
n = 0.01
g = 0.02
s = 0.36
alpha = 0.333333
E = 1
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

# 4.3 For n = 0.01, g= 0.02, δ = .03, α = 0.3333, 
# s = 0.36, and E = 1.

YoverL43 = 2.45
KoverL43 = 14.75

# %%
# 4.4 For n = .01, g= 0.02, δ = .03, α = 0.4, 
# s = 0.50, and E = 1.

YoverL44 = ___
KoverL44 = ___

# %%
# ANSWER

delta = 0.03
n = 0.01
g = 0.02
s = 0.50
alpha = 0.4
E = 1
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[120:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 120               30.00           3.898060                   3.60
# 121               30.25           3.911021                   3.63
# 122               30.50           3.923918                   3.66
# 123               30.75           3.936752                   3.69
# 124               31.00           3.949523                   3.72
# 125               31.25           3.962233                   3.75
# 126               31.50           3.974882                   3.78
# 127               31.75           3.987471                   3.81
# 128               32.00           4.000000                   3.84
# 129               32.25           4.012471                   3.87
# 130               32.50           4.024884                   3.90
# 131               32.75           4.037240                   3.93
# 132               33.00           4.049539                   3.96
# 133               33.25           4.061782                   3.99
# 134               33.50           4.073971                   4.02
# 135               33.75           4.086105                   4.05
# 136               34.00           4.098185                   4.08
# 137               34.25           4.110212                   4.11
# 138               34.50           4.122187                   4.14
# 139               34.75           4.134109                   4.17
# 140               35.00           4.145980                   4.20
# 141               35.25           4.157801                   4.23
# 142               35.50           4.169571                   4.26
# 143               35.75           4.181291                   4.29
# 144               36.00           4.192963                   4.32
# 145               36.25           4.204586                   4.35
# 146               36.50           4.216161                   4.38
# 147               36.75           4.227688                   4.41
# 148               37.00           4.239169                   4.44
# 149               37.25           4.250603                   4.47
# ..                  ...                ...                    ...
# 171               42.75           4.491325                   5.13
# 172               43.00           4.501812                   5.16
# 173               43.25           4.512263                   5.19
# 174               43.50           4.522678                   5.22
# 175               43.75           4.533057                   5.25
# 176               44.00           4.543401                   5.28
# 177               44.25           4.553709                   5.31
# 178               44.50           4.563983                   5.34
# 179               44.75           4.574222                   5.37
# 180               45.00           4.584426                   5.40
# 181               45.25           4.594597                   5.43
# 182               45.50           4.604734                   5.46
# 183               45.75           4.614838                   5.49
# 184               46.00           4.624908                   5.52
# 185               46.25           4.634946                   5.55
# 186               46.50           4.644951                   5.58
# 187               46.75           4.654925                   5.61
# 188               47.00           4.664866                   5.64
# 189               47.25           4.674775                   5.67
# 190               47.50           4.684653                   5.70
# 191               47.75           4.694500                   5.73
# 192               48.00           4.704316                   5.76
# 193               48.25           4.714101                   5.79
# 194               48.50           4.723856                   5.82
# 195               48.75           4.733581                   5.85
# 196               49.00           4.743276                   5.88
# 197               49.25           4.752942                   5.91
# 198               49.50           4.762578                   5.94
# 199               49.75           4.772185                   5.97
# 200               50.00           4.781762                   6.00
#
# [81 rows x 3 columns]

# %%
# ANSWER

# 4.4 For n = .01, g= 0.02, δ = .03, α = 0.4, 
# s = 0.50, and E = 1.

YoverL44 = 4.11
KoverL44 = 34.25

# %%
# 4.5 For n = .01, g= 0.02, δ = .03, α = 0.2, 
# s = 0.50, and E = 1.

YoverL45 = ___
KoverL45 = ___

# %%
# ANSWER

delta = 0.03
n = 0.01
g = 0.02
s = 0.50
alpha = 0.2
E = 1
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[80:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 80                20.00           4.308869                   4.00
# 81                20.25           4.326748                   4.05
# 82                20.50           4.344481                   4.10
# 83                20.75           4.362070                   4.15
# 84                21.00           4.379519                   4.20
# 85                21.25           4.396829                   4.25
# 86                21.50           4.414005                   4.30
# 87                21.75           4.431047                   4.35
# 88                22.00           4.447960                   4.40
# 89                22.25           4.464745                   4.45
# 90                22.50           4.481404                   4.50
# 91                22.75           4.497941                   4.55
# 92                23.00           4.514357                   4.60
# 93                23.25           4.530655                   4.65
# 94                23.50           4.546836                   4.70
# 95                23.75           4.562902                   4.75
# 96                24.00           4.578857                   4.80
# 97                24.25           4.594701                   4.85
# 98                24.50           4.610436                   4.90
# 99                24.75           4.626065                   4.95
# 100               25.00           4.641588                   5.00
# 101               25.25           4.657009                   5.05
# 102               25.50           4.672328                   5.10
# 103               25.75           4.687548                   5.15
# 104               26.00           4.702669                   5.20
# 105               26.25           4.717694                   5.25
# 106               26.50           4.732623                   5.30
# 107               26.75           4.747459                   5.35
# 108               27.00           4.762203                   5.40
# 109               27.25           4.776856                   5.45
# ..                  ...                ...                    ...
# 171               42.75           5.550499                   8.55
# 172               43.00           5.561297                   8.60
# 173               43.25           5.572054                   8.65
# 174               43.50           5.582770                   8.70
# 175               43.75           5.593444                   8.75
# 176               44.00           5.604078                   8.80
# 177               44.25           5.614672                   8.85
# 178               44.50           5.625226                   8.90
# 179               44.75           5.635740                   8.95
# 180               45.00           5.646216                   9.00
# 181               45.25           5.656652                   9.05
# 182               45.50           5.667051                   9.10
# 183               45.75           5.677411                   9.15
# 184               46.00           5.687733                   9.20
# 185               46.25           5.698019                   9.25
# 186               46.50           5.708267                   9.30
# 187               46.75           5.718478                   9.35
# 188               47.00           5.728654                   9.40
# 189               47.25           5.738793                   9.45
# 190               47.50           5.748896                   9.50
# 191               47.75           5.758965                   9.55
# 192               48.00           5.768998                   9.60
# 193               48.25           5.778996                   9.65
# 194               48.50           5.788960                   9.70
# 195               48.75           5.798889                   9.75
# 196               49.00           5.808785                   9.80
# 197               49.25           5.818647                   9.85
# 198               49.50           5.828476                   9.90
# 199               49.75           5.838272                   9.95
# 200               50.00           5.848035                  10.00
#
# [121 rows x 3 columns]

# %%
# ANSWER

4.5 For n = .01, g= 0.02, δ = .03, α = 0.2, 
# s = 0.50, and E = 1.

YoverL45 = 4.47
KoverL45 = 22.375

# %%
# 4.6 For n = .005, g= 0.015, δ = .03, α = 0.33333, 
# s = 0.50, and E = 1

YoverL46 = ___
KoverL46 = ___

# %%
# ANSWER

delta = 0.03
n = 0.005
g = 0.015
s = 0.50
alpha = 0.333333
E = 1
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[100:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 100               25.00           2.924015                  2.500
# 101               25.25           2.933729                  2.525
# 102               25.50           2.943379                  2.550
# 103               25.75           2.952967                  2.575
# 104               26.00           2.962493                  2.600
# 105               26.25           2.971958                  2.625
# 106               26.50           2.981363                  2.650
# 107               26.75           2.990709                  2.675
# 108               27.00           2.999997                  2.700
# 109               27.25           3.009228                  2.725
# 110               27.50           3.018402                  2.750
# 111               27.75           3.027521                  2.775
# 112               28.00           3.036586                  2.800
# 113               28.25           3.045596                  2.825
# 114               28.50           3.054554                  2.850
# 115               28.75           3.063459                  2.875
# 116               29.00           3.072313                  2.900
# 117               29.25           3.081117                  2.925
# 118               29.50           3.089870                  2.950
# 119               29.75           3.098574                  2.975
# 120               30.00           3.107229                  3.000
# 121               30.25           3.115836                  3.025
# 122               30.50           3.124396                  3.050
# 123               30.75           3.132910                  3.075
# 124               31.00           3.141377                  3.100
# 125               31.25           3.149799                  3.125
# 126               31.50           3.158176                  3.150
# 127               31.75           3.166509                  3.175
# 128               32.00           3.174798                  3.200
# 129               32.25           3.183045                  3.225
# ..                  ...                ...                    ...
# 171               42.75           3.496591                  4.275
# 172               43.00           3.503394                  4.300
# 173               43.25           3.510170                  4.325
# 174               43.50           3.516920                  4.350
# 175               43.75           3.523645                  4.375
# 176               44.00           3.530344                  4.400
# 177               44.25           3.537018                  4.425
# 178               44.50           3.543666                  4.450
# 179               44.75           3.550290                  4.475
# 180               45.00           3.556889                  4.500
# 181               45.25           3.563463                  4.525
# 182               45.50           3.570014                  4.550
# 183               45.75           3.576540                  4.575
# 184               46.00           3.583043                  4.600
# 185               46.25           3.589523                  4.625
# 186               46.50           3.595979                  4.650
# 187               46.75           3.602411                  4.675
# 188               47.00           3.608821                  4.700
# 189               47.25           3.615209                  4.725
# 190               47.50           3.621574                  4.750
# 191               47.75           3.627916                  4.775
# 192               48.00           3.634236                  4.800
# 193               48.25           3.640535                  4.825
# 194               48.50           3.646812                  4.850
# 195               48.75           3.653067                  4.875
# 196               49.00           3.659301                  4.900
# 197               49.25           3.665514                  4.925
# 198               49.50           3.671705                  4.950
# 199               49.75           3.677876                  4.975
# 200               50.00           3.684027                  5.000
#
# [101 rows x 3 columns]

# %%
# ANSWER

# 4.6 For n = .005, g= 0.015, δ = .03, α = 0.33333, 
# s = 0.50, and E = 1

YoverL46 = 3.16
KoverL46 = 31.5

# %%
# 4.7 For n = .005, g= 0.015, δ = .03, α = 0.75, 
# s = 0.125, and E = 0.5

YoverL47 = ___
KoverL47 = ___

# %%
# ANSWER

delta = 0.03
n = 0.005
g = 0.015
s = 0.125
alpha = 0.75
E = 0.5
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[60:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 60                15.00           6.409305                    6.0
# 61                15.25           6.489256                    6.1
# 62                15.50           6.568879                    6.2
# 63                15.75           6.648182                    6.3
# 64                16.00           6.727171                    6.4
# 65                16.25           6.805852                    6.5
# 66                16.50           6.884231                    6.6
# 67                16.75           6.962314                    6.7
# 68                17.00           7.040106                    6.8
# 69                17.25           7.117612                    6.9
# 70                17.50           7.194838                    7.0
# 71                17.75           7.271789                    7.1
# 72                18.00           7.348469                    7.2
# 73                18.25           7.424884                    7.3
# 74                18.50           7.501037                    7.4
# 75                18.75           7.576933                    7.5
# 76                19.00           7.652577                    7.6
# 77                19.25           7.727972                    7.7
# 78                19.50           7.803123                    7.8
# 79                19.75           7.878034                    7.9
# 80                20.00           7.952707                    8.0
# 81                20.25           8.027148                    8.1
# 82                20.50           8.101359                    8.2
# 83                20.75           8.175345                    8.3
# 84                21.00           8.249108                    8.4
# 85                21.25           8.322651                    8.5
# 86                21.50           8.395979                    8.6
# 87                21.75           8.469094                    8.7
# 88                22.00           8.541999                    8.8
# 89                22.25           8.614697                    8.9
# ..                  ...                ...                    ...
# 171               42.75          14.058681                   17.1
# 172               43.00          14.120297                   17.2
# 173               43.25          14.181824                   17.3
# 174               43.50          14.243261                   17.4
# 175               43.75          14.304611                   17.5
# 176               44.00          14.365873                   17.6
# 177               44.25          14.427047                   17.7
# 178               44.50          14.488136                   17.8
# 179               44.75          14.549139                   17.9
# 180               45.00          14.610056                   18.0
# 181               45.25          14.670889                   18.1
# 182               45.50          14.731638                   18.2
# 183               45.75          14.792304                   18.3
# 184               46.00          14.852887                   18.4
# 185               46.25          14.913388                   18.5
# 186               46.50          14.973806                   18.6
# 187               46.75          15.034144                   18.7
# 188               47.00          15.094401                   18.8
# 189               47.25          15.154578                   18.9
# 190               47.50          15.214676                   19.0
# 191               47.75          15.274695                   19.1
# 192               48.00          15.334635                   19.2
# 193               48.25          15.394497                   19.3
# 194               48.50          15.454281                   19.4
# 195               48.75          15.513989                   19.5
# 196               49.00          15.573620                   19.6
# 197               49.25          15.633175                   19.7
# 198               49.50          15.692654                   19.8
# 199               49.75          15.752058                   19.9
# 200               50.00          15.811388                   20.0
#
# [141 rows x 3 columns]

# %%
# ANSWER

# 4.7 For n = .005, g= 0.015, δ = .03, α = 0.75, 
# s = 0.125, and E = 0.5

YoverL47 = 7.8
KoverL47 = 19.5

# %%
# 4.8 For n = .015, g= 0.015, δ = .03, α = 0.75, 
# s = 0.25, and E = 0.1

YoverL48 = ___
KoverL48 = ___

# %%
# ANSWER

delta = 0.03
n = 0.005
g = 0.015
s = 0.25
alpha = 0.75
E = 0.05
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[100:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 100               25.00           5.286856                   5.00
# 101               25.25           5.326458                   5.05
# 102               25.50           5.365963                   5.10
# 103               25.75           5.405370                   5.15
# 104               26.00           5.444682                   5.20
# 105               26.25           5.483899                   5.25
# 106               26.50           5.523024                   5.30
# 107               26.75           5.562056                   5.35
# 108               27.00           5.600997                   5.40
# 109               27.25           5.639848                   5.45
# 110               27.50           5.678610                   5.50
# 111               27.75           5.717284                   5.55
# 112               28.00           5.755871                   5.60
# 113               28.25           5.794372                   5.65
# 114               28.50           5.832787                   5.70
# 115               28.75           5.871119                   5.75
# 116               29.00           5.909368                   5.80
# 117               29.25           5.947534                   5.85
# 118               29.50           5.985618                   5.90
# 119               29.75           6.023622                   5.95
# 120               30.00           6.061547                   6.00
# 121               30.25           6.099392                   6.05
# 122               30.50           6.137159                   6.10
# 123               30.75           6.174849                   6.15
# 124               31.00           6.212462                   6.20
# 125               31.25           6.250000                   6.25
# 126               31.50           6.287463                   6.30
# 127               31.75           6.324851                   6.35
# 128               32.00           6.362166                   6.40
# 129               32.25           6.399408                   6.45
# ..                  ...                ...                    ...
# 171               42.75           7.905778                   8.55
# 172               43.00           7.940427                   8.60
# 173               43.25           7.975026                   8.65
# 174               43.50           8.009574                   8.70
# 175               43.75           8.044074                   8.75
# 176               44.00           8.078524                   8.80
# 177               44.25           8.112925                   8.85
# 178               44.50           8.147278                   8.90
# 179               44.75           8.181582                   8.95
# 180               45.00           8.215838                   9.00
# 181               45.25           8.250047                   9.05
# 182               45.50           8.284209                   9.10
# 183               45.75           8.318324                   9.15
# 184               46.00           8.352392                   9.20
# 185               46.25           8.386414                   9.25
# 186               46.50           8.420390                   9.30
# 187               46.75           8.454321                   9.35
# 188               47.00           8.488206                   9.40
# 189               47.25           8.522046                   9.45
# 190               47.50           8.555841                   9.50
# 191               47.75           8.589592                   9.55
# 192               48.00           8.623299                   9.60
# 193               48.25           8.656962                   9.65
# 194               48.50           8.690581                   9.70
# 195               48.75           8.724157                   9.75
# 196               49.00           8.757690                   9.80
# 197               49.25           8.791180                   9.85
# 198               49.50           8.824628                   9.90
# 199               49.75           8.858033                   9.95
# 200               50.00           8.891397                  10.00
#
# [101 rows x 3 columns]

# %%
# ANSWER

# 4.8 For n = .015, g= 0.015, δ = .03, α = 0.75, 
# s = 0.25, and E = 0.5

YoverL48 = 6.25
KoverL48 = 31.25

# %%
# 4.9 For n = .015, g= 0.015, δ = .03, α = 0.5, 
# s = 0.5, and E = 0.5

YoverL49 = ___
KoverL49 = ___

# %%
# ANSWER

delta = 0.03
n = 0.005
g = 0.015
s = 0.50
alpha = 0.5
E = 0.25
lowestKoverLconsidered = 0

#----

array = np.zeros((201, 3))

for i in range(201):
    array[i, 0] = lowestKoverLconsidered + i/4
    array[i, 1] = (array[i, 0] 
        ** alpha) * E**(1 - alpha)
    array[i, 2] = ((delta + n + g)/s * array[i, 0] )

capital_and_output_per_worker_df = DataFrame(data = 
    array, columns = ["Capital_per_Worker", "Output_per_Worker", 
    "Equilibrium Condition"])

capital_and_output_per_worker_df.set_index('Capital_per_Worker').plot()

plt.xlabel("Capital per Worker")
plt.ylabel("Output per Worker")
plt.ylim(0, )
plt.title("Balanced Growth Equilibrium Is Where the Curves Cross", size = 20)
# Out:
# Text(0.5,1,'Balanced Growth Equilibrium Is Where the Curves Cross')

# %%
# ANSWER

capital_and_output_per_worker_df[80:]
# Out:
#      Capital_per_Worker  Output_per_Worker  Equilibrium Condition
# 80                20.00           2.236068                  2.000
# 81                20.25           2.250000                  2.025
# 82                20.50           2.263846                  2.050
# 83                20.75           2.277608                  2.075
# 84                21.00           2.291288                  2.100
# 85                21.25           2.304886                  2.125
# 86                21.50           2.318405                  2.150
# 87                21.75           2.331845                  2.175
# 88                22.00           2.345208                  2.200
# 89                22.25           2.358495                  2.225
# 90                22.50           2.371708                  2.250
# 91                22.75           2.384848                  2.275
# 92                23.00           2.397916                  2.300
# 93                23.25           2.410913                  2.325
# 94                23.50           2.423840                  2.350
# 95                23.75           2.436699                  2.375
# 96                24.00           2.449490                  2.400
# 97                24.25           2.462214                  2.425
# 98                24.50           2.474874                  2.450
# 99                24.75           2.487469                  2.475
# 100               25.00           2.500000                  2.500
# 101               25.25           2.512469                  2.525
# 102               25.50           2.524876                  2.550
# 103               25.75           2.537223                  2.575
# 104               26.00           2.549510                  2.600
# 105               26.25           2.561738                  2.625
# 106               26.50           2.573908                  2.650
# 107               26.75           2.586020                  2.675
# 108               27.00           2.598076                  2.700
# 109               27.25           2.610077                  2.725
# ..                  ...                ...                    ...
# 171               42.75           3.269174                  4.275
# 172               43.00           3.278719                  4.300
# 173               43.25           3.288237                  4.325
# 174               43.50           3.297726                  4.350
# 175               43.75           3.307189                  4.375
# 176               44.00           3.316625                  4.400
# 177               44.25           3.326034                  4.425
# 178               44.50           3.335416                  4.450
# 179               44.75           3.344772                  4.475
# 180               45.00           3.354102                  4.500
# 181               45.25           3.363406                  4.525
# 182               45.50           3.372684                  4.550
# 183               45.75           3.381937                  4.575
# 184               46.00           3.391165                  4.600
# 185               46.25           3.400368                  4.625
# 186               46.50           3.409545                  4.650
# 187               46.75           3.418699                  4.675
# 188               47.00           3.427827                  4.700
# 189               47.25           3.436932                  4.725
# 190               47.50           3.446012                  4.750
# 191               47.75           3.455069                  4.775
# 192               48.00           3.464102                  4.800
# 193               48.25           3.473111                  4.825
# 194               48.50           3.482097                  4.850
# 195               48.75           3.491060                  4.875
# 196               49.00           3.500000                  4.900
# 197               49.25           3.508917                  4.925
# 198               49.50           3.517812                  4.950
# 199               49.75           3.526684                  4.975
# 200               50.00           3.535534                  5.000
#
# [121 rows x 3 columns]

# %%
# ANSWER

# 4.9 For n = .015, g= 0.015, δ = .03, α = 0.5, 
# s = 0.5, and E = 0.5

YoverL49 = 2.5
KoverL49 = 25

# %% [markdown]
# ----
#
# &nbsp;

# %%
_ = ok.submit()
# Out:
# Saving notebook... Saved 'PS4.ipynb'.
# Submit... 0.0% complete
# Could not submit: Late Submission of cal/econ101b/sp18/PS4
